# %% [markdown]
# <a href="https://colab.research.google.com/github/ZaidiSahab/Road-to-Data-Science/blob/main/Learning_From_Youtube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Practicing Calculations For the Total Profit**

# %%
single_bag_cost =1.25

# %%
overall_profit =0.2

# %%
total_bags=500

# %%
overall_profit= single_bag_cost* total_bags * overall_profit

# %%
overall_profit

# %%
print("The total Profit of 500 Bag is :" ,overall_profit)

# %% [markdown]
# #Now Practicing Faviorate Number

# %%
# !.[_].()

# %%
print("My faviourate number is 2")

# %% [markdown]
# ##DATA LABELS In python

# %%
x = "rate"

# %%
type(x)

# %%
fruits= ["apple", 3,"keeno"]

# %%
print(fruits)

# %%
print("The type of list is:", type(fruits))

# %%
x= range(100)

# %%
print(x)

# %%
print(list(x))

# %% [markdown]
# ####TUPLE

# %%
veggies =("cucumber" , "tomatoes", "potatoes")

# %%
print(type(veggies))

# %% [markdown]
# ###SET

# %%
cricket ={"ball", "bat", "wicket" , True , 2 , 1}

# %%
cricket

# %%
cricket ={"ball", "bat", "wicket" , True , 2 , 1, False ,0}

# %%
print(cricket)

# %%
print(type(cricket))

# %% [markdown]
# ###Dictionaries

# %%
football ={"player1": "Ronaldo","player2": "messi" , "goat": "rolando" , "goat": "rooney"}

# %%
football

# %%
print(football["goat"])

# %%
print(len(football))

# %% [markdown]
# ##IF Condition

# %%
x =33

# %%
y=44

# %%
if y>x:
  print("Y is heighest" )

# %% [markdown]
# ##If Condition with Score Board of Students

# %%
Score = input("Write your marks:")
Score_In_Integer =int(Score)
print(Score_In_Integer)

# %%
if Score_In_Integer <=50:
  print ("You are fail with marks: ", Score)

elif Score_In_Integer >=51 :

  print ("You are Passed with marks: ", Score)

# %% [markdown]
# ###IF Else

# %%
my_dict = {
  "Name": "John Doe",
  "age": 30,
  "city": "New York"
}

print(my_dict)

# %%
if "Name" in my_dict:
  print("Name key exists")

# %%
fullInfo=({"Name": "Ronaldo",
          "Shirt No." : 7,
          "team":"Real Madrid"},
          {"Name": "Messi",
          "Shirt No." : 10,
          "team":"Barcelona"})

# %%
fullInfo

# %%
for "Name" in fullInfo:
  print("Name")

# %% [markdown]
# #Practicing last day work

# %% [markdown]
# ###List

# %%
fruit = ["apple", "bananna"]

# %%
print(fruit)

# %% [markdown]
# ###Tuple

# %%
fruit = ("apple", "bananna")

# %%
fruit

# %% [markdown]
# ###Dictionany

# %%
fruit = {"red" : "apple" ,"yellow": "bananna"}

# %%
print(fruit)

# %% [markdown]
# ###IF Elif Else Conditions Usecase

# %%
if "red" in fruit:
  print ("red", "is present")
elif "yellow" in fruit:
  print ("yellow", "is present")
else:
  print("You entered wrong input!")

# %% [markdown]
# ###For Loop

# %%
for x in fruit:
  print(fruit)

# %%
for x in "banana":
  print(x)

# %%
for x in fruits:
  print(x)

# %% [markdown]
# ###Function Build Up

# %%
def my_function():
  print("Hello from a function")
my_function()

# %%
print(my_function())

# %% [markdown]
# ###Factorial Example:

# %%
n= input("Enter the number:")
n= int(n)
def factorial(n):
  if n==0 or n==1:
    return 1
  else:
    return n* factorial(n-1)
print("The Factorial of",n, "is",factorial(n))

# %% [markdown]
# ###If Using Double Quotations

# %%
print("what a\'re you doing here")

# %% [markdown]
# ###Capitalize

# %%
name ="Mustafa zaidi"

name.capitalize()
name.lower()
name.upper()

# %% [markdown]
# ###Numpy

# %%
import numpy as np
a = np.array([1, 2, 3, 4])

# %%
b = np.array([1, 2, 3, 4])
c=a+b

# %%
a_reshape =a.reshape(2,2)
a_reshape

# %%
arr1 = np.array([1, 2, 3, 4, 5, 6])
arr1_reshaped = arr1.reshape((2, 3))
print("Example 1:\n", arr1_reshaped)

# %% [markdown]
# #Started Working on Pandas and Numpy and Uploading CSV files

# %%
import pandas as pd

# %%
df =pd.read_excel('/content/Lookup.xlsx')

# %%
df.head(6)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df.head()

# %%
df.isnull().sum()

# %%
df.shape

# %% [markdown]
# ##Counting Total Number of Rows in Data

# %%
num_rows = df.shape[1]
print(num_rows)

# %%
total_rows = df.shape[0]
total_rows

# %%
df.info()

# %%
print(df.iloc[0:5])

# %%
 df.values

# %%
df.describe()

# %%
df.info()

# %%
df.tail(9)

# %%
df.dtypes

# %% [markdown]
# ###Sorting And Filtering

# %%
df[df['Net Salary']>100000].head()

# %%
name = df[df['NAME']=='Danish Ghayas']

# %%
name

# %%
df[df[120720].isin("Net Salary")]

# %%
df[['NAME', 'Net Salary']]

# %%
df.sort_values(by ="Net Salary" , ascending=False)

# %%
df.dropna()

# %%
df.head()

# %%
name = df.groupby('NAME')['Net Salary'].mean()

# %%
print(name)

# %%
name = df.groupby('NAME')['Net Salary'].agg('mean','min','max')

# %%
print(name)

# %% [markdown]
# ##USING MATPLOTLIB LIBRARY

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('/content/Lookup.xlsx')
plt.plot(df['BASIC'])

# %% [markdown]
# Plot Title

# %%
plt.title("SCORE RESULT")
plt.xlabel("Values")
plt.ylabel("Score")
plt.plot(df['Net Salary'])
plt.show()

# %%
plt.hist(df['BASIC'], bins=10)

# %% [markdown]
# ##No practice on 19/12/25

# %%
#No Printing today

# %%
import seaborn as sns
sns.set_theme()

# %%
df = sns.load_dataset("tips")
print(df.head(8))

sns.set_theme()

# %% [markdown]
# ##Plot

# %%
sns.countplot(x="NAME", data=df)
plt.title("Count of Students by Gender")
plt.show()

# %% [markdown]
# ##Again revising the previus Concept

# %%
n =input("Enter the number:")
n = int(n)
def fact(n):

  if n==0 or n==1:
    return 1
  else:
    return n* fact(n-1)

print("The factorial of" , n ,"is",factorial(n) )

# %% [markdown]
# ##Histogram

# %%
sns.histplot(df['Net Salary'], bins=9 )
plt.title("Math Score Distribution")
plt.show()

# %% [markdown]
# ##Box Plot

# %%
sns.boxplot(y='Designation', x='Net Salary', data=df)
plt.title("Math Score by Gender")
plt.show()

# %% [markdown]
# ##BARPLOT

# %%
sns.barplot(x="BASIC", y="NAME" ,data=df)
plt.title("Dataset")
plt.show()

# %%
sns.scatterplot(x="Net Salary" , y= "NAME" , data=df)
plt.show()

# %% [markdown]
# HEAT MAP

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
sns.set(style="whitegrid")

# %%
sns.pairplot(df[['Net Salary','BASIC','NAME']])

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib as plt

# %%
df = pd.read_excel('/content/Lookup.xlsx')

# %%
df.head()

# %%
df.describe()

# %%
df.info()

# %%
df.isnull().sum()

# %% [markdown]
# #Starting A New Phase

# %% [markdown]
# #**Alex The Analyst**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/content/Customer Call List (1).xlsx')

# %%
df.head()

# %%
df = df.drop_duplicates()

# %%
#df["Last_Name"] = df["Last_Name"].str.lstrip('...')
#df["Last_Name"] = df["Last_Name"].str.lstrip('/')
#df["Last_Name"] = df["Last_Name"].str.rstrip('_')


df["Last_Name"] = df["Last_Name"].str.strip('123./_')
# Out:
# /tmp/ipython-input-4208243767.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Last_Name"] = df["Last_Name"].str.strip('123./_')

# %%
#df["Phone_Number"].str.replace('[^a-zA-Z0-9]','')

#df["Phone_Number"] = df["Phone_Number"].apply(lambda x: x[0:3] +'-'+ x[3:6] +'-' + x[6:10])
#df["Phone_Number"] = df["Phone_Number"].apply(lambda x: str(x))
df

# %%
df["Phone_Number"] = df["Phone_Number"].astype(str).str.replace(r'[^0-9]', '', regex=True)
df["Phone_Number"] = df["Phone_Number"].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10] if len(x) >= 10 else x)
# Out:
# /tmp/ipython-input-2323602485.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"] = df["Phone_Number"].astype(str).str.replace(r'[^0-9]', '', regex=True)
# /tmp/ipython-input-2323602485.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"] = df["Phone_Number"].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10] if len(x) >= 10 else x)

# %%
df

# %%
df['Phone_Number'].str.replace("nan--","")

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# ...

# %%
df = df.drop(columns = "Not_Useful_Column")

# %%
df['Address']

# %%
df[["Street_Address", "State", "Zip_Code"]] = df['Address'].str.split(',', n=2, expand=True)
# Out:
# /tmp/ipython-input-1053776574.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["Street_Address", "State", "Zip_Code"]] = df['Address'].str.split(',', n=2, expand=True)
# /tmp/ipython-input-1053776574.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["Street_Address", "State", "Zip_Code"]] = df['Address'].str.split(',', n=2, expand=True)
# /tmp/ipython-input-1053776574.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df["Paying Customer"] = df["Paying Customer"].str.replace("Yes", "Y")
df["Paying Customer"] = df["Paying Customer"].str.replace("No", "N")
df
# Out:
# /tmp/ipython-input-2655812887.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Paying Customer"] = df["Paying Customer"].str.replace("Yes", "Y")
# /tmp/ipython-input-2655812887.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Paying Customer"] = df["Paying Customer"].str.replace("No", "N")
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# ...

# %%
df['Do_Not_Contact'] = df["Do_Not_Contact"].str.replace("Yes", "Y")
df['Do_Not_Contact'] = df["Do_Not_Contact"].str.replace("No", "N")
df
# Out:
# /tmp/ipython-input-2132133528.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Do_Not_Contact'] = df["Do_Not_Contact"].str.replace("Yes", "Y")
# /tmp/ipython-input-2132133528.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Do_Not_Contact'] = df["Do_Not_Contact"].str.replace("No", "N")
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# ...

# %%
print("LAST COMMIT")

# %%
df.fillna("")
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# ...

# %% [markdown]
# #Using Pandas

# %%
import pandas as pd
import numpy  as np
import seaborn as sns

df= pd.read_excel('/content/Customer Call List (1).xlsx')

df['CustomerID'].mean()
# Out:
# np.float64(1010.952380952381)

# %%
df.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %%
np.median(df['CustomerID'])
# Out:
# np.float64(1011.0)

# %%
np.std(df['CustomerID'])
# Out:
# 5.979936219409754

# %%
df['CustomerID'].describe()
# Out:
# count      21.000000
# mean     1010.952381
# std         6.127611
# min      1001.000000
# 25%      1006.000000
# 50%      1011.000000
# 75%      1016.000000
# max      1020.000000
# Name: CustomerID, dtype: float64

# %%
df = pd.read_excel("/content/Day15_Statistics_Practice.xlsx")

# %%
df['math_score'].mean()
# Out:
# np.float64(78.7)

# %% [markdown]
# #Average Scores Comparison of Male And Female

# %%
import pandas as pd
df = pd.read_excel("/content/Day15_Statistics_Practice.xlsx")

def result():
  # Calculate the mean math score for males
  male_math_score_mean = df[df['gender'] == 'male']['math_score'].mean()

  # Calculate the mean math score for females
  female_math_score_mean = df[df['gender'] == 'female']['math_score'].mean()

  if male_math_score_mean == female_math_score_mean:
    print("Both scores are equal")
  elif male_math_score_mean > female_math_score_mean:
    print("Male scores are higher")
  else:
    print("Female scores are higher")

result()
# Out:
# Female scores are higher

# %%
def male():
  male_score = df[df['gender']=="male"] ['math_score'].mean()
  female_score = df[df['gender']=="female"]['math_score'].mean()
  if male_score==female_score:
    print("Both scores are equal")
  elif male_score> female_score:
    print("Male scores are higher")
  else:
    print("Female scores are higher")

male()
# Out:
# Female scores are higher

# %%
df["gender"] = df['gender'].str.replace("male", "M")
df["gender"] =df["gender"].str.replace("female", "F")

df
# Out:
#   gender  math_score  reading_score  writing_score
# 0      M          78             74             72
# 1      F          85             88             90
# 2      F          67             70             68
# 3      M          90             92             94
# 4      F          72             75             78
# 5      M          88             85             87
# 6      M          60             65             62
# 7      F          95             90             93
# 8      M          70             68             66
# 9      F          82             80             84

# %% [markdown]
# #Which is the heighest Score

# %%
def Variance():
  math_Score= df["math_score"].std()
  reading_score= df["reading_score"].std()
  writing_Score= df["writing_score"].std()

  if math_Score==reading_score==writing_Score:
      print("All scores are equal")
  elif math_Score>reading_score>writing_Score:
      print("Math scores are higher:",math_Score)
  elif reading_score>math_Score>writing_Score:
      print("Reading scores are higher:", reading_score)
  else:
      print("Writing scores are higher:",writing_Score)

Variance()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2801647877.py in <cell line: 0>()
#      13       print("Writing scores are higher:",writing_Score)
#      14
# ---> 15 Variance()
#
# /tmp/ipython-input-2801647877.py in Variance()
#       1 def Variance():
# ----> 2   math_Score= df["math_score"].std()
#       3   reading_score= df["reading_score"].std()
#       4   writing_Score= df["writing_score"].std()
#       5
#
# NameError: name 'df' is not defined

# %%
df['math_score'].corr(df['reading_score'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'math_score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3973083944.py in <cell line: 0>()
# ----> 1 df['math_score'].corr(df['reading_score'])
#
# ...

# %%
df.head()
# Out:
#    gender  math_score  reading_score  writing_score
# 0    male          78             74             72
# 1  female          85             88             90
# 2  female          67             70             68
# 3    male          90             92             94
# 4  female          72             75             78

# %%
df= df.drop(columns="gender")

# %%
correlation = df.corr()

# %%
correlation.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_b2602_row0_col0, #T_b2602_row1_col1, #T_b2602_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b2602_row0_col1, #T_b2602_row0_col2, #T_b2602_row2_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b2602_row1_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_b2602_row1_col2 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_b2602_row2_col1 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b2602" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2602_level0_col0" class="col_heading level0 col0" >math_score</th>
#       <th id="T_b2602_level0_col1" class="col_heading level0 col1" >reading_score</th>
#       <th id="T_b2602_level0_col2" class="col_heading level0 col2" >writing_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
import seaborn as sns
sns.pairplot(df)

# %%
df[["math_score","reading_score","writing_score"]].corr()
# Out:
#                math_score  reading_score  writing_score
# math_score       1.000000       0.952921       0.943564
# reading_score    0.952921       1.000000       0.989670
# writing_score    0.943564       0.989670       1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(
    df[['math_score','reading_score','writing_score']].corr(),
    cmap='coolwarm'
    ,annot=True
)
plt.show()

# %%
sns.scatterplot(x='math_score', y='reading_score', data=df)
# Out:
# <Axes: xlabel='math_score', ylabel='reading_score'>
